# %% [markdown]
# ## Pandas

# %% [markdown]
# #### Author: Chun Ting Chang
# #### Github: https://github.com/ChunTingChang

# %% [markdown]
# ![category](table_of_contents.png)

# %% [markdown]
# ## Intro <br/>
# - Pandas is a library for **data manipulation and analysis**
# - Pandas offers **data structures and operations** for manipulating numerical tables and time series

# %%
import pandas as pd
pd.options.mode.chained_assignment = None # to hide SettingWithCopyWarning

# %% [markdown]
# ### Before we start
#
# ```python
# import pandas as pd
# ```

# %% [markdown]
# ### Series VS DataFrame
#
# - Series: 1-dimensional labeled array
# - DataFrame: 2-dimensional labeled data structure
#
# ```python
# for col in df.columns:
#     series = df[col]
# ```

# %% [markdown]
# ### Create a new Series and DataFrame
# - Convert list to Series

# %%
new_ser = pd.Series()
new_df = pd.DataFrame()

sample_list_1 = [10, 20, 30]
sample_ser_1 = pd.Series(sample_list_1)
sample_ser_1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# ### Create a new Series and DataFrame
# - Convert Dict to DataFrame

# %%
# len of list(values) shall be the same
a = {'name': ['a', 'b', 'c'], 'gender': ['f','m','m']}
a = pd.DataFrame(a)
a
# Out:
#   name gender
# 0    a      f
# 1    b      m
# 2    c      m

# %%
# keys can be different
b = {'name': 'a', 'gender': 'f', 'age': 5}, {'name': 'b', 'gender': 'm', 'age': 15}, {'name': 'c', 'gender':'m', 'age': 25}, {'name': 'c', 'gender':'m'}
b = pd.DataFrame(b) 
b
# Out:
#     age gender name
# 0   5.0      f    a
# 1  15.0      m    b
# 2  25.0      m    c
# 3   NaN      m    c

# %% [markdown]
# ## How to import data to python?

# %% [markdown]
# ### Import data
# - Excel, CSV, JSON, SQL, etc.
# ```python
# pd.read_csv(path)
# ```
# - parameter: header, sep, index_col, etc.

# %%
path = "train.csv"

file = pd.read_csv(path)
file.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
print(type(file.survived))
print(type(file))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# If import a dataset without a header

file_no_header = pd.read_csv(path, header = None) # use index as a temporary header (row index)
file_no_header.head()
# Out:
#          0       1                                                  2   \
# 0  survived  pclass                                               name
# 1         0       3                            Braund, Mr. Owen Harris
# 2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       3                             Heikkinen, Miss. Laina
# 4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
#        3    4      5      6                 7        8      9         10
# 0     sex  age  sibsp  parch            ticket     fare  cabin  embarked
# 1    male   22      1      0         A/5 21171     7.25    NaN         S
# 2  female   38      1      0          PC 17599  71.2833    C85         C
# 3  female   26      0      0  STON/O2. 3101282    7.925    NaN         S
# 4  female   35      1      0            113803     53.1   C123         S

# %%
# rename the header

file_no_header = file_no_header.rename(columns={0: "a", 1: "b"})
file_no_header.head()
# Out:
#           a       b                                                  2  \
# 0  survived  pclass                                               name
# 1         0       3                            Braund, Mr. Owen Harris
# 2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       3                             Heikkinen, Miss. Laina
# 4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
#         3    4      5      6                 7        8      9        10
# 0     sex  age  sibsp  parch            ticket     fare  cabin  embarked
# 1    male   22      1      0         A/5 21171     7.25    NaN         S
# 2  female   38      1      0          PC 17599  71.2833    C85         C
# 3  female   26      0      0  STON/O2. 3101282    7.925    NaN         S
# 4  female   35      1      0            113803     53.1   C123         S

# %%
# rename the index

file_no_header = file_no_header.rename(index={0: "a", 1: "b"})
file_no_header.head()
# Out:
#           a       b                                                  2  \
# a  survived  pclass                                               name
# b         0       3                            Braund, Mr. Owen Harris
# 2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       3                             Heikkinen, Miss. Laina
# 4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
#         3    4      5      6                 7        8      9        10
# a     sex  age  sibsp  parch            ticket     fare  cabin  embarked
# b    male   22      1      0         A/5 21171     7.25    NaN         S
# 2  female   38      1      0          PC 17599  71.2833    C85         C
# 3  female   26      0      0  STON/O2. 3101282    7.925    NaN         S
# 4  female   35      1      0            113803     53.1   C123         S

# %%
# If you have index in the dataset

file_index_col = pd.read_csv(path, index_col = ['name', 'survived']) # use 'name' as column index
file_index_col.head()
# Out:
#                                                              pclass     sex  \
# name                                               survived
# Braund, Mr. Owen Harris                            0              3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha... 1              1  female
# Heikkinen, Miss. Laina                             1              3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1              1  female
# Allen, Mr. William Henry                           0              3    male
#
#                                                               age  sibsp  \
# name                                               survived
# Braund, Mr. Owen Harris                            0         22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha... 1         38.0      1
# Heikkinen, Miss. Laina                             1         26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         35.0      1
# Allen, Mr. William Henry                           0         35.0      0
#
#                                                              parch  \
# name                                               survived
# Braund, Mr. Owen Harris                            0             0
# Cumings, Mrs. John Bradley (Florence Briggs Tha... 1             0
# Heikkinen, Miss. Laina                             1             0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1             0
# Allen, Mr. William Henry                           0             0
#
#                                                                        ticket  \
# name                                               survived
# Braund, Mr. Owen Harris                            0                A/5 21171
# Cumings, Mrs. John Bradley (Florence Briggs Tha... 1                 PC 17599
# Heikkinen, Miss. Laina                             1         STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1                   113803
# Allen, Mr. William Henry                           0                   373450
#
#                                                                 fare cabin  \
# name                                               survived
# Braund, Mr. Owen Harris                            0          7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha... 1         71.2833   C85
# Heikkinen, Miss. Laina                             1          7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         53.1000  C123
# Allen, Mr. William Henry                           0          8.0500   NaN
#
#                                                             embarked
# name                                               survived
# Braund, Mr. Owen Harris                            0               S
# Cumings, Mrs. John Bradley (Florence Briggs Tha... 1               C
# Heikkinen, Miss. Laina                             1               S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1               S
# Allen, Mr. William Henry                           0               S

# %% [markdown]
# ### Get to know your data
# - columns
# - head
# - tail
# - sample
# - describe
# - info

# %%
file.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
file.tail()
# Out:
#      survived  pclass                                      name     sex   age  \
# 886         0       2                     Montvila, Rev. Juozas    male  27.0
# 887         1       1              Graham, Miss. Margaret Edith  female  19.0
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889         1       1                     Behr, Mr. Karl Howell    male  26.0
# 890         0       3                       Dooley, Mr. Patrick    male  32.0
#
#      sibsp  parch      ticket   fare cabin embarked
# 886      0      0      211536  13.00   NaN        S
# 887      0      0      112053  30.00   B42        S
# 888      1      2  W./C. 6607  23.45   NaN        S
# 889      0      0      111369  30.00  C148        C
# 890      0      0      370376   7.75   NaN        Q

# %%
file.sample() # default: output 1 row
# Out:
#      survived  pclass                       name   sex   age  sibsp  parch  \
# 616         0       3  Danbom, Mr. Ernst Gilbert  male  34.0      1      1
#
#      ticket  fare cabin embarked
# 616  347080  14.4   NaN        S

# %%
file.sample(5)
# Out:
#      survived  pclass                                           name     sex  \
# 20          0       2                           Fynney, Mr. Joseph J    male
# 91          0       3                     Andreasson, Mr. Paul Edvin    male
# 251         0       3     Strom, Mrs. Wilhelm (Elna Matilda Persson)  female
# 791         0       2                            Gaskell, Mr. Alfred    male
# 133         1       2  Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female
#
#       age  sibsp  parch  ticket     fare cabin embarked
# 20   35.0      0      0  239865  26.0000   NaN        S
# 91   20.0      0      0  347466   7.8542   NaN        S
# 251  29.0      1      1  347054  10.4625    G6        S
# 791  16.0      0      0  239865  26.0000   NaN        S
# 133  29.0      1      0  228414  26.0000   NaN        S

# %%
file.info() # see data type, data size, and na value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# name        891 non-null object
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# ticket      891 non-null object
# fare        891 non-null float64
# cabin       204 non-null object
# embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB

# %%
file.describe() # only for float/integer
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
file.age.mean()
# Out:
# 29.69911764705882

# %%
file.age.sum()
# Out:
# 21205.17

# %%
file.age.min()
# Out:
# 0.42

# %%
file.age.max()
# Out:
# 80.0

# %%
file.count()
# Out:
# survived    891
# pclass      891
# name        891
# sex         891
# age         714
# sibsp       891
# parch       891
# ticket      891
# fare        891
# cabin       204
# embarked    889
# dtype: int64

# %%
file.nunique()
# Out:
# survived      2
# pclass        3
# name        891
# sex           2
# age          88
# sibsp         7
# parch         7
# ticket      681
# fare        248
# cabin       147
# embarked      3
# dtype: int64

# %%
file.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %% [markdown]
# ## How to trim my dataset?

# %% [markdown]
# ### Select and slice data
#
# ```python
# df['col_name']
# df[True/ False condition]
# df.loc/ df.iloc
# ```

# %%
file['name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: name, dtype: object

# %%
file[['name', 'survived']].head()
# Out:
#                                                 name  survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                           Allen, Mr. William Henry         0

# %%
# select 2 columns and top 5th-9th rows 

file[['name', 'survived']][5:10]
# Out:
#                                                 name  survived
# 5                                   Moran, Mr. James         0
# 6                            McCarthy, Mr. Timothy J         0
# 7                     Palsson, Master. Gosta Leonard         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1

# %%
# iloc select: index
file.iloc[5:10,:8] # [5:10] end_value excl.
# Out:
#    survived  pclass                                               name  \
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex   age  sibsp  parch  ticket
# 5    male   NaN      0      0  330877
# 6    male  54.0      0      0   17463
# 7    male   2.0      3      1  349909
# 8  female  27.0      0      2  347742
# 9  female  14.0      1      0  237736

# %%
# loc select: column/ row name
file.loc[5:10,:'ticket'] # [5:10] end_value inclu.
# Out:
#     survived  pclass                                               name  \
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
#
#        sex   age  sibsp  parch   ticket
# 5     male   NaN      0      0   330877
# 6     male  54.0      0      0    17463
# 7     male   2.0      3      1   349909
# 8   female  27.0      0      2   347742
# 9   female  14.0      1      0   237736
# 10  female   4.0      1      1  PP 9549

# %%
file.iloc[[0,1],[0,7]]
# Out:
#    survived     ticket
# 0         0  A/5 21171
# 1         1   PC 17599

# %%
file.loc[[0,1],['survived','ticket']]
# Out:
#    survived     ticket
# 0         0  A/5 21171
# 1         1   PC 17599

# %%
file[file.age > 60] # == file[file['age'] > 60]
# Out:
#      survived  pclass                                       name     sex  \
# 33          0       2                      Wheadon, Mr. Edward H    male
# 54          0       1             Ostby, Mr. Engelhart Cornelius    male
# 96          0       1                  Goldschmidt, Mr. George B    male
# 116         0       3                       Connors, Mr. Patrick    male
# 170         0       1                  Van der hoef, Mr. Wyckoff    male
# 252         0       1                  Stead, Mr. William Thomas    male
# 275         1       1          Andrews, Miss. Kornelia Theodosia  female
# 280         0       3                           Duane, Mr. Frank    male
# 326         0       3                  Nysveen, Mr. Johan Hansen    male
# 438         0       1                          Fortune, Mr. Mark    male
# 456         0       1                  Millet, Mr. Francis Davis    male
# 483         1       3                     Turkula, Mrs. (Hedwig)  female
# 493         0       1                    Artagaveytia, Mr. Ramon    male
# 545         0       1               Nicholson, Mr. Arthur Ernest    male
# 555         0       1                         Wright, Mr. George    male
# 570         1       2                         Harris, Mr. George    male
# 625         0       1                      Sutton, Mr. Frederick    male
# 630         1       1       Barkworth, Mr. Algernon Henry Wilson    male
# 672         0       2                Mitchell, Mr. Henry Michael    male
# 745         0       1               Crosby, Capt. Edward Gifford    male
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)  female
# 851         0       3                        Svensson, Mr. Johan    male
#
#       age  sibsp  parch       ticket      fare        cabin embarked
# 33   66.0      0      0   C.A. 24579   10.5000          NaN        S
# 54   65.0      0      1       113509   61.9792          B30        C
# 96   71.0      0      0     PC 17754   34.6542           A5        C
# 116  70.5      0      0       370369    7.7500          NaN        Q
# 170  61.0      0      0       111240   33.5000          B19        S
# 252  62.0      0      0       113514   26.5500          C87        S
# 275  63.0      1      0        13502   77.9583           D7        S
# 280  65.0      0      0       336439    7.7500          NaN        Q
# 326  61.0      0      0       345364    6.2375          NaN        S
# 438  64.0      1      4        19950  263.0000  C23 C25 C27        S
# 456  65.0      0      0        13509   26.5500          E38        S
# 483  63.0      0      0         4134    9.5875          NaN        S
# 493  71.0      0      0     PC 17609   49.5042          NaN        C
# 545  64.0      0      0          693   26.0000          NaN        S
# 555  62.0      0      0       113807   26.5500          NaN        S
# 570  62.0      0      0  S.W./PP 752   10.5000          NaN        S
# 625  61.0      0      0        36963   32.3208          D50        S
# 630  80.0      0      0        27042   30.0000          A23        S
# 672  70.0      0      0   C.A. 24580   10.5000          NaN        S
# 745  70.0      1      1    WE/P 5735   71.0000          B22        S
# 829  62.0      0      0       113572   80.0000          B28      NaN
# 851  74.0      0      0       347060    7.7750          NaN        S

# %%
file[(file.age > 60) & (file.sex == 'female')] # & == AND
# Out:
#      survived  pclass                                       name     sex  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia  female
# 483         1       3                     Turkula, Mrs. (Hedwig)  female
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       age  sibsp  parch  ticket     fare cabin embarked
# 275  63.0      1      0   13502  77.9583    D7        S
# 483  63.0      0      0    4134   9.5875   NaN        S
# 829  62.0      0      0  113572  80.0000   B28      NaN

# %%
file[(file.age > 60) | (file.sex == 'female')] # | == OR
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 14          0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 18          0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19          1       3                            Masselmani, Mrs. Fatima
# 22          1       3                        McGowan, Miss. Anna "Annie"
# 24          0       3                      Palsson, Miss. Torborg Danira
# 25          1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 28          1       3                      O'Dwyer, Miss. Ellen "Nellie"
# 31          1       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 32          1       3                           Glynn, Miss. Mary Agatha
# 33          0       2                              Wheadon, Mr. Edward H
# 38          0       3                 Vander Planke, Miss. Augusta Maria
# 39          1       3                        Nicola-Yarred, Miss. Jamila
# 40          0       3     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 41          0       2  Turpin, Mrs. William John Robert (Dorothy Ann ...
# 43          1       2           Laroche, Miss. Simonne Marie Anne Andree
# 44          1       3                      Devaney, Miss. Margaret Delia
# 47          1       3                          O'Driscoll, Miss. Bridget
# 49          0       3      Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# 52          1       1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 53          1       2  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...
# 54          0       1                     Ostby, Mr. Engelhart Cornelius
# 56          1       2                                  Rugg, Miss. Emily
# ..        ...     ...                                                ...
# 809         1       1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 813         0       3                 Andersson, Miss. Ebba Iris Alfrida
# 816         0       3                       Heininen, Miss. Wendla Maria
# 820         1       1  Hays, Mrs. Charles Melville (Clara Jennings Gr...
# 823         1       3                                 Moor, Mrs. (Beila)
# 829         1       1          Stone, Mrs. George Nelson (Martha Evelyn)
# 830         1       3            Yasbeck, Mrs. Antoni (Selini Alexander)
# 835         1       1                        Compton, Miss. Sara Rebecca
# 842         1       1                            Serepeca, Miss. Augusta
# 849         1       1       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 851         0       3                                Svensson, Mr. Johan
# 852         0       3                            Boulos, Miss. Nourelain
# 853         1       1                          Lines, Miss. Mary Conover
# 854         0       2      Carter, Mrs. Ernest Courtenay (Lilian Hughes)
# 855         1       3                         Aks, Mrs. Sam (Leah Rosen)
# 856         1       1         Wick, Mrs. George Dennick (Mary Hitchcock)
# 858         1       3              Baclini, Mrs. Solomon (Latifa Qurban)
# 862         1       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863         0       3                  Sage, Miss. Dorothy Edith "Dolly"
# 865         1       2                           Bystrom, Mrs. (Karolina)
# 866         1       2                       Duran y More, Miss. Asuncion
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874         1       2              Abelson, Mrs. Samuel (Hannah Wizosky)
# 875         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 882         0       3                       Dahlberg, Miss. Gerda Ulrika
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
#
#         sex   age  sibsp  parch            ticket      fare cabin embarked
# 1    female  38.0      1      0          PC 17599   71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282    7.9250   NaN        S
# 3    female  35.0      1      0            113803   53.1000  C123        S
# 8    female  27.0      0      2            347742   11.1333   NaN        S
# 9    female  14.0      1      0            237736   30.0708   NaN        C
# 10   female   4.0      1      1           PP 9549   16.7000    G6        S
# 11   female  58.0      0      0            113783   26.5500  C103        S
# 14   female  14.0      0      0            350406    7.8542   NaN        S
# 15   female  55.0      0      0            248706   16.0000   NaN        S
# 18   female  31.0      1      0            345763   18.0000   NaN        S
# 19   female   NaN      0      0              2649    7.2250   NaN        C
# 22   female  15.0      0      0            330923    8.0292   NaN        Q
# 24   female   8.0      3      1            349909   21.0750   NaN        S
# 25   female  38.0      1      5            347077   31.3875   NaN        S
# 28   female   NaN      0      0            330959    7.8792   NaN        Q
# 31   female   NaN      1      0          PC 17569  146.5208   B78        C
# 32   female   NaN      0      0            335677    7.7500   NaN        Q
# 33     male  66.0      0      0        C.A. 24579   10.5000   NaN        S
# 38   female  18.0      2      0            345764   18.0000   NaN        S
# 39   female  14.0      1      0              2651   11.2417   NaN        C
# 40   female  40.0      1      0              7546    9.4750   NaN        S
# 41   female  27.0      1      0             11668   21.0000   NaN        S
# 43   female   3.0      1      2     SC/Paris 2123   41.5792   NaN        C
# 44   female  19.0      0      0            330958    7.8792   NaN        Q
# 47   female   NaN      0      0             14311    7.7500   NaN        Q
# 49   female  18.0      1      0            349237   17.8000   NaN        S
# 52   female  49.0      1      0          PC 17572   76.7292   D33        C
# 53   female  29.0      1      0              2926   26.0000   NaN        S
# 54     male  65.0      0      1            113509   61.9792   B30        C
# 56   female  21.0      0      0        C.A. 31026   10.5000   NaN        S
# ..      ...   ...    ...    ...               ...       ...   ...      ...
# 809  female  33.0      1      0            113806   53.1000    E8        S
# 813  female   6.0      4      2            347082   31.2750   NaN        S
# 816  female  23.0      0      0  STON/O2. 3101290    7.9250   NaN        S
# 820  female  52.0      1      1             12749   93.5000   B69        S
# 823  female  27.0      0      1            392096   12.4750  E121        S
# 829  female  62.0      0      0            113572   80.0000   B28      NaN
# 830  female  15.0      1      0              2659   14.4542   NaN        C
# 835  female  39.0      1      1          PC 17756   83.1583   E49        C
# 842  female  30.0      0      0            113798   31.0000   NaN        C
# 849  female   NaN      1      0             17453   89.1042   C92        C
# 851    male  74.0      0      0            347060    7.7750   NaN        S
# 852  female   9.0      1      1              2678   15.2458   NaN        C
# 853  female  16.0      0      1          PC 17592   39.4000   D28        S
# 854  female  44.0      1      0            244252   26.0000   NaN        S
# 855  female  18.0      0      1            392091    9.3500   NaN        S
# 856  female  45.0      1      1             36928  164.8667   NaN        S
# 858  female  24.0      0      3              2666   19.2583   NaN        C
# 862  female  48.0      0      0             17466   25.9292   D17        S
# 863  female   NaN      8      2          CA. 2343   69.5500   NaN        S
# 865  female  42.0      0      0            236852   13.0000   NaN        S
# 866  female  27.0      1      0     SC/PARIS 2149   13.8583   NaN        C
# 871  female  47.0      1      1             11751   52.5542   D35        S
# 874  female  28.0      1      0         P/PP 3381   24.0000   NaN        C
# 875  female  15.0      0      0              2667    7.2250   NaN        C
# 879  female  56.0      0      1             11767   83.1583   C50        C
# 880  female  25.0      0      1            230433   26.0000   NaN        S
# 882  female  22.0      0      0              7552   10.5167   NaN        S
# 885  female  39.0      0      5            382652   29.1250   NaN        Q
# 887  female  19.0      0      0            112053   30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607   23.4500   NaN        S
#
# [333 rows x 11 columns]

# %% [markdown]
# ## How to add/ delete column(s)?
# - add
# ```python
# df.append()
# ```
# - delete
# ```python
# del df['col_name']
# df.drop()
# df.pop()
# ```

# %% [markdown]
# ### Add new column to a DataFrame
# - df['new_col_name'] = pd.Series/ list/ str/ float

# %%
# If we want to insert a new column called `fare_lv`

a_file = file.copy() 
a_file['fare_lv'] = ''
a_file.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   fare_lv
# 0
# 1
# 2
# 3
# 4

# %%
fare_lv_series = pd.qcut(file['fare'], 3, labels = ["low", "medium", "high"])
# age_lv = pd.qcut(file['age'], 3, labels = ["young", "medium", "old"])

# b_file = pd.DataFrame([fare_lv, age_lv]).T
# b_file = b_file.rename(columns = {'age':'age_lv', 'fare':'fare_lv'})

# %%
# We have an existing pandas series called `fare_lv_series`

print(type(fare_lv_series), '\n')
print(fare_lv_series.head(3))
# Out:
# <class 'pandas.core.series.Series'>
#
# 0     low
# 1    high
# 2     low
# Name: fare, dtype: category
# Categories (3, object): [low < medium < high]

# %%
# We insert `fare_lv_series` as values in `fare_lv` column in a_file

a_file['fare_lv'] = fare_lv_series
a_file.head(5)
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   fare_lv
# 0     low
# 1    high
# 2     low
# 3    high
# 4     low

# %% [markdown]
# ### Add new row to a DataFrame
# - df.append()

# %%
for_add_row = "C:/Users/angela/Downloads/kaggle-titanic-master/kaggle-titanic-master/test.csv"
add_row = pd.read_csv(for_add_row)
add_row['survived'] = 1
add_row = add_row[:5]

# %%
# We have an existing pandas dataframe called `add_row`

add_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
# pclass      5 non-null int64
# name        5 non-null object
# sex         5 non-null object
# age         5 non-null float64
# sibsp       5 non-null int64
# parch       5 non-null int64
# ticket      5 non-null object
# fare        5 non-null float64
# cabin       0 non-null object
# embarked    5 non-null object
# survived    5 non-null int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 520.0+ bytes

# %%
add_row
# Out:
#    pclass                                          name     sex   age  sibsp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    parch   ticket     fare cabin embarked  survived
# 0      0   330911   7.8292   NaN        Q         1
# 1      0   363272   7.0000   NaN        S         1
# 2      0   240276   9.6875   NaN        Q         1
# 3      0   315154   8.6625   NaN        S         1
# 4      1  3101298  12.2875   NaN        S         1

# %%
# To insert `add_row` into a_file

a_file = a_file.append(add_row)
a_file.tail(10)
# Out:
# C:\Users\angela\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#       age cabin embarked     fare fare_lv  \
# 886  27.0   NaN        S  13.0000  medium
# 887  19.0   B42        S  30.0000    high
# 888   NaN   NaN        S  23.4500  medium
# 889  26.0  C148        C  30.0000    high
# 890  32.0   NaN        Q   7.7500     low
# 0    34.5   NaN        Q   7.8292     NaN
# 1    47.0   NaN        S   7.0000     NaN
# 2    62.0   NaN        Q   9.6875     NaN
# 3    27.0   NaN        S   8.6625     NaN
# 4    22.0   NaN        S  12.2875     NaN
#
#                                              name  parch  pclass     sex  \
# 886                         Montvila, Rev. Juozas      0       2    male
# 887                  Graham, Miss. Margaret Edith      0       1  female
# 888      Johnston, Miss. Catherine Helen "Carrie"      2       3  female
# 889                         Behr, Mr. Karl Howell      0       1    male
# 890                           Dooley, Mr. Patrick      0       3    male
# 0                                Kelly, Mr. James      0       3    male
# 1                Wilkes, Mrs. James (Ellen Needs)      0       3  female
# 2                       Myles, Mr. Thomas Francis      0       2    male
# 3                                Wirz, Mr. Albert      0       3    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1       3  female
#
#      sibsp  survived      ticket
# 886      0         0      211536
# 887      0         1      112053
# 888      1         0  W./C. 6607
# 889      0         1      111369
# 890      0         0      370376
# 0        0         1      330911
# 1        1         1      363272
# 2        0         1      240276
# 3        0         1      315154
# 4        1         1     3101298

# %% [markdown]
# ### Remove column(s) from a DataFrame
# ```python
# del df['col_name']
# ```

# %%
del a_file['cabin']
a_file.head(5)
# Out:
#     age embarked     fare fare_lv  \
# 0  22.0        S   7.2500     low
# 1  38.0        C  71.2833    high
# 2  26.0        S   7.9250     low
# 3  35.0        S  53.1000    high
# 4  35.0        S   8.0500     low
#
#                                                 name  parch  pclass     sex  \
# 0                            Braund, Mr. Owen Harris      0       3    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1  female
# 2                             Heikkinen, Miss. Laina      0       3  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1  female
# 4                           Allen, Mr. William Henry      0       3    male
#
#    sibsp  survived            ticket
# 0      1         0         A/5 21171
# 1      1         1          PC 17599
# 2      0         1  STON/O2. 3101282
# 3      1         1            113803
# 4      0         0            373450

# %% [markdown]
# ### Remove column(s) from a DataFrame
# ```python
# df.pop()
# ```

# %%
a_file.pop('name').head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: name, dtype: object

# %%
a_file.head()
# Out:
#     age embarked     fare fare_lv  parch  pclass     sex  sibsp  survived  \
# 0  22.0        S   7.2500     low      0       3    male      1         0
# 1  38.0        C  71.2833    high      0       1  female      1         1
# 2  26.0        S   7.9250     low      0       3  female      0         1
# 3  35.0        S  53.1000    high      0       1  female      1         1
# 4  35.0        S   8.0500     low      0       3    male      0         0
#
#              ticket
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803
# 4            373450

# %% [markdown]
# ### Remove column(s)/ row(s) from a DataFrame
# ```python
# df.drop()
# ```

# %%
a_file.drop(columns = ['parch', 'sibsp']).head()
# Out:
#     age embarked     fare fare_lv  pclass     sex  survived            ticket
# 0  22.0        S   7.2500     low       3    male         0         A/5 21171
# 1  38.0        C  71.2833    high       1  female         1          PC 17599
# 2  26.0        S   7.9250     low       3  female         1  STON/O2. 3101282
# 3  35.0        S  53.1000    high       1  female         1            113803
# 4  35.0        S   8.0500     low       3    male         0            373450

# %%
a_file.drop(index = [0, 1]).head()
# if not `a_file = a_file.drop(index = [0, 1])`, then the drop execution won't be saved as a_file
# Out:
#     age embarked     fare fare_lv  parch  pclass     sex  sibsp  survived  \
# 2  26.0        S   7.9250     low      0       3  female      0         1
# 3  35.0        S  53.1000    high      0       1  female      1         1
# 4  35.0        S   8.0500     low      0       3    male      0         0
# 5   NaN        Q   8.4583     low      0       3    male      0         0
# 6  54.0        S  51.8625    high      0       1    male      0         0
#
#              ticket
# 2  STON/O2. 3101282
# 3            113803
# 4            373450
# 5            330877
# 6             17463

# %% [markdown]
# ## If we have na value in our dataset ...
#
# ```python
# print(file.info())
# ```
#
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# name        891 non-null object
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# ticket      891 non-null object
# fare        891 non-null float64
# cabin       204 non-null object
# embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB
# ```

# %% [markdown]
# ### There are some columns incl. Na value:
# - age
# - cabin
# - embarked

# %% [markdown]
# ### How to deal with Na value in the dataset:
# - fillna
# - dropna

# %%
age_na = file[file.age.isnull()]
age_na.head(5)
# Out:
#     survived  pclass                           name     sex  age  sibsp  \
# 5          0       3               Moran, Mr. James    male  NaN      0
# 17         1       2   Williams, Mr. Charles Eugene    male  NaN      0
# 19         1       3        Masselmani, Mrs. Fatima  female  NaN      0
# 26         0       3        Emir, Mr. Farred Chehab    male  NaN      0
# 28         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
#
#     parch  ticket     fare cabin embarked
# 5       0  330877   8.4583   NaN        Q
# 17      0  244373  13.0000   NaN        S
# 19      0    2649   7.2250   NaN        C
# 26      0    2631   7.2250   NaN        C
# 28      0  330959   7.8792   NaN        Q

# %%
age_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177 entries, 5 to 888
# Data columns (total 11 columns):
# survived    177 non-null int64
# pclass      177 non-null int64
# name        177 non-null object
# sex         177 non-null object
# age         0 non-null float64
# sibsp       177 non-null int64
# parch       177 non-null int64
# ticket      177 non-null object
# fare        177 non-null float64
# cabin       19 non-null object
# embarked    177 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 16.6+ KB

# %%
age_na.age.fillna(0).sample(5)
# Out:
# 837    0.0
# 464    0.0
# 295    0.0
# 223    0.0
# 511    0.0
# Name: age, dtype: float64

# %%
sample_age = file.copy()
# int(sample_age.age.mean()) == 29

age_na.age.fillna(int(sample_age.age.mean())).sample(5)
# Out:
# 485    29.0
# 364    29.0
# 459    29.0
# 783    29.0
# 475    29.0
# Name: age, dtype: float64

# %%
# fill na value with the value ahead 
# eg. if row 5 has na value and row 4 has non-na value, value in row 5 will be filled with value in row 4
# `age` in row 5, 17, 19 were na value
sample_age.fillna(method = 'ffill').head(20)
# Out:
#     survived  pclass                                               name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# 12         0       3                     Saundercock, Mr. William Henry
# 13         0       3                        Andersson, Mr. Anders Johan
# 14         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16         0       3                               Rice, Master. Eugene
# 17         1       2                       Williams, Mr. Charles Eugene
# 18         0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19         1       3                            Masselmani, Mrs. Fatima
#
#        sex   age  sibsp  parch            ticket     fare cabin embarked
# 0     male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1   female  38.0      1      0          PC 17599  71.2833   C85        C
# 2   female  26.0      0      0  STON/O2. 3101282   7.9250   C85        S
# 3   female  35.0      1      0            113803  53.1000  C123        S
# 4     male  35.0      0      0            373450   8.0500  C123        S
# 5     male  35.0      0      0            330877   8.4583  C123        Q
# 6     male  54.0      0      0             17463  51.8625   E46        S
# 7     male   2.0      3      1            349909  21.0750   E46        S
# 8   female  27.0      0      2            347742  11.1333   E46        S
# 9   female  14.0      1      0            237736  30.0708   E46        C
# 10  female   4.0      1      1           PP 9549  16.7000    G6        S
# 11  female  58.0      0      0            113783  26.5500  C103        S
# 12    male  20.0      0      0         A/5. 2151   8.0500  C103        S
# 13    male  39.0      1      5            347082  31.2750  C103        S
# 14  female  14.0      0      0            350406   7.8542  C103        S
# 15  female  55.0      0      0            248706  16.0000  C103        S
# 16    male   2.0      4      1            382652  29.1250  C103        Q
# 17    male   2.0      0      0            244373  13.0000  C103        S
# 18  female  31.0      1      0            345763  18.0000  C103        S
# 19  female  31.0      0      0              2649   7.2250  C103        C

# %%
sample_age.dropna() # default: how = 'any'
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 21          1       2                              Beesley, Mr. Lawrence
# 23          1       1                       Sloper, Mr. William Thompson
# 27          0       1                     Fortune, Mr. Charles Alexander
# 52          1       1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 54          0       1                     Ostby, Mr. Engelhart Cornelius
# 62          0       1                        Harris, Mr. Henry Birkhardt
# 66          1       2                       Nye, Mrs. (Elizabeth Ramell)
# 75          0       3                            Moen, Mr. Sigurd Hansen
# 88          1       1                         Fortune, Miss. Mabel Helen
# 92          0       1                        Chaffee, Mr. Herbert Fuller
# 96          0       1                          Goldschmidt, Mr. George B
# 97          1       1                    Greenfield, Mr. William Bertram
# 102         0       1                          White, Mr. Richard Frasar
# 110         0       1                     Porter, Mr. Walter Chamberlain
# 118         0       1                           Baxter, Mr. Quigg Edmond
# 123         1       2                                Webber, Miss. Susan
# 124         0       1                        White, Mr. Percival Wayland
# 136         1       1                       Newsom, Miss. Helen Monypeny
# 137         0       1                        Futrelle, Mr. Jacques Heath
# 139         0       1                                 Giglio, Mr. Victor
# 148         0       2           Navratil, Mr. Michel ("Louis M Hoffman")
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 170         0       1                          Van der hoef, Mr. Wyckoff
# 174         0       1                            Smith, Mr. James Clinch
# 177         0       1                         Isham, Miss. Ann Elizabeth
# ..        ...     ...                                                ...
# 737         1       1                             Lesurer, Mr. Gustave J
# 741         0       1                      Cavendish, Mr. Tyrell William
# 742         1       1              Ryerson, Miss. Susan Parker "Suzette"
# 745         0       1                       Crosby, Capt. Edward Gifford
# 748         0       1                          Marvin, Mr. Daniel Warner
# 751         1       3                                Moor, Master. Meier
# 759         1       1  Rothes, the Countess. of (Lucy Noel Martha Dye...
# 763         1       1          Carter, Mrs. William Ernest (Lucile Polk)
# 765         1       1               Hogeboom, Mrs. John C (Anna Andrews)
# 772         0       2                                  Mack, Mrs. (Mary)
# 779         1       1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 781         1       1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 782         0       1                             Long, Mr. Milton Clyde
# 789         0       1                           Guggenheim, Mr. Benjamin
# 796         1       1                        Leader, Dr. Alice (Farnham)
# 802         1       1                Carter, Master. William Thornton II
# 806         0       1                             Andrews, Mr. Thomas Jr
# 809         1       1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 820         1       1  Hays, Mrs. Charles Melville (Clara Jennings Gr...
# 823         1       3                                 Moor, Mrs. (Beila)
# 835         1       1                        Compton, Miss. Sara Rebecca
# 853         1       1                          Lines, Miss. Mary Conover
# 857         1       1                             Daly, Mr. Peter Denis
# 862         1       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 867         0       1               Roebling, Mr. Washington Augustus II
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         sex   age  sibsp  parch       ticket      fare            cabin  \
# 1    female  38.0      1      0     PC 17599   71.2833              C85
# 3    female  35.0      1      0       113803   53.1000             C123
# 6      male  54.0      0      0        17463   51.8625              E46
# 10   female   4.0      1      1      PP 9549   16.7000               G6
# 11   female  58.0      0      0       113783   26.5500             C103
# 21     male  34.0      0      0       248698   13.0000              D56
# 23     male  28.0      0      0       113788   35.5000               A6
# 27     male  19.0      3      2        19950  263.0000      C23 C25 C27
# 52   female  49.0      1      0     PC 17572   76.7292              D33
# 54     male  65.0      0      1       113509   61.9792              B30
# 62     male  45.0      1      0        36973   83.4750              C83
# 66   female  29.0      0      0   C.A. 29395   10.5000              F33
# 75     male  25.0      0      0       348123    7.6500            F G73
# 88   female  23.0      3      2        19950  263.0000      C23 C25 C27
# 92     male  46.0      1      0  W.E.P. 5734   61.1750              E31
# 96     male  71.0      0      0     PC 17754   34.6542               A5
# 97     male  23.0      0      1     PC 17759   63.3583          D10 D12
# 102    male  21.0      0      1        35281   77.2875              D26
# 110    male  47.0      0      0       110465   52.0000             C110
# 118    male  24.0      0      1     PC 17558  247.5208          B58 B60
# 123  female  32.5      0      0        27267   13.0000             E101
# 124    male  54.0      0      1        35281   77.2875              D26
# 136  female  19.0      0      2        11752   26.2833              D47
# 137    male  37.0      1      0       113803   53.1000             C123
# 139    male  24.0      0      0     PC 17593   79.2000              B86
# 148    male  36.5      0      2       230080   26.0000               F2
# 151  female  22.0      1      0       113776   66.6000               C2
# 170    male  61.0      0      0       111240   33.5000              B19
# 174    male  56.0      0      0        17764   30.6958               A7
# 177  female  50.0      0      0     PC 17595   28.7125              C49
# ..      ...   ...    ...    ...          ...       ...              ...
# 737    male  35.0      0      0     PC 17755  512.3292             B101
# 741    male  36.0      1      0        19877   78.8500              C46
# 742  female  21.0      2      2     PC 17608  262.3750  B57 B59 B63 B66
# 745    male  70.0      1      1    WE/P 5735   71.0000              B22
# 748    male  19.0      1      0       113773   53.1000              D30
# 751    male   6.0      0      1       392096   12.4750             E121
# 759  female  33.0      0      0       110152   86.5000              B77
# 763  female  36.0      1      2       113760  120.0000          B96 B98
# 765  female  51.0      1      0        13502   77.9583              D11
# 772  female  57.0      0      0  S.O./P.P. 3   10.5000              E77
# 779  female  43.0      0      1        24160  211.3375               B3
# 781  female  17.0      1      0        17474   57.0000              B20
# 782    male  29.0      0      0       113501   30.0000               D6
# 789    male  46.0      0      0     PC 17593   79.2000          B82 B84
# 796  female  49.0      0      0        17465   25.9292              D17
# 802    male  11.0      1      2       113760  120.0000          B96 B98
# 806    male  39.0      0      0       112050    0.0000              A36
# 809  female  33.0      1      0       113806   53.1000               E8
# 820  female  52.0      1      1        12749   93.5000              B69
# 823  female  27.0      0      1       392096   12.4750             E121
# 835  female  39.0      1      1     PC 17756   83.1583              E49
# 853  female  16.0      0      1     PC 17592   39.4000              D28
# 857    male  51.0      0      0       113055   26.5500              E17
# 862  female  48.0      0      0        17466   25.9292              D17
# 867    male  31.0      0      0     PC 17590   50.4958              A24
# 871  female  47.0      1      1        11751   52.5542              D35
# 872    male  33.0      0      0          695    5.0000      B51 B53 B55
# 879  female  56.0      0      1        11767   83.1583              C50
# 887  female  19.0      0      0       112053   30.0000              B42
# 889    male  26.0      0      0       111369   30.0000             C148
#
#     embarked
# 1          C
# 3          S
# 6          S
# 10         S
# 11         S
# 21         S
# 23         S
# 27         S
# 52         C
# 54         C
# 62         S
# 66         S
# 75         S
# 88         S
# 92         S
# 96         C
# 97         C
# 102        S
# 110        S
# 118        C
# 123        S
# 124        S
# 136        S
# 137        S
# 139        C
# 148        S
# 151        S
# 170        S
# 174        C
# 177        C
# ..       ...
# 737        C
# 741        S
# 742        C
# 745        S
# 748        S
# 751        S
# 759        S
# 763        S
# 765        S
# 772        S
# 779        S
# 781        S
# 782        S
# 789        C
# 796        S
# 802        S
# 806        S
# 809        S
# 820        S
# 823        S
# 835        C
# 853        S
# 857        S
# 862        S
# 867        S
# 871        S
# 872        S
# 879        C
# 887        S
# 889        C
#
# [183 rows x 11 columns]

# %%
sample_age.dropna(how = 'all')
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 12          0       3                     Saundercock, Mr. William Henry
# 13          0       3                        Andersson, Mr. Anders Johan
# 14          0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16          0       3                               Rice, Master. Eugene
# 17          1       2                       Williams, Mr. Charles Eugene
# 18          0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19          1       3                            Masselmani, Mrs. Fatima
# 20          0       2                               Fynney, Mr. Joseph J
# 21          1       2                              Beesley, Mr. Lawrence
# 22          1       3                        McGowan, Miss. Anna "Annie"
# 23          1       1                       Sloper, Mr. William Thompson
# 24          0       3                      Palsson, Miss. Torborg Danira
# 25          1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26          0       3                            Emir, Mr. Farred Chehab
# 27          0       1                     Fortune, Mr. Charles Alexander
# 28          1       3                      O'Dwyer, Miss. Ellen "Nellie"
# 29          0       3                                Todoroff, Mr. Lalio
# ..        ...     ...                                                ...
# 861         0       2                        Giles, Mr. Frederick Edward
# 862         1       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863         0       3                  Sage, Miss. Dorothy Edith "Dolly"
# 864         0       2                             Gill, Mr. John William
# 865         1       2                           Bystrom, Mrs. (Karolina)
# 866         1       2                       Duran y More, Miss. Asuncion
# 867         0       1               Roebling, Mr. Washington Augustus II
# 868         0       3                        van Melkebeke, Mr. Philemon
# 869         1       3                    Johnson, Master. Harold Theodor
# 870         0       3                                  Balkic, Mr. Cerin
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 873         0       3                        Vander Cruyssen, Mr. Victor
# 874         1       2              Abelson, Mrs. Samuel (Hannah Wizosky)
# 875         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 876         0       3                      Gustafsson, Mr. Alfred Ossian
# 877         0       3                               Petroff, Mr. Nedelio
# 878         0       3                                 Laleff, Mr. Kristo
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 881         0       3                                 Markun, Mr. Johann
# 882         0       3                       Dahlberg, Miss. Gerda Ulrika
# 883         0       2                      Banfield, Mr. Frederick James
# 884         0       3                             Sutehall, Mr. Henry Jr
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket      fare        cabin  \
# 0      male  22.0      1      0         A/5 21171    7.2500          NaN
# 1    female  38.0      1      0          PC 17599   71.2833          C85
# 2    female  26.0      0      0  STON/O2. 3101282    7.9250          NaN
# 3    female  35.0      1      0            113803   53.1000         C123
# 4      male  35.0      0      0            373450    8.0500          NaN
# 5      male   NaN      0      0            330877    8.4583          NaN
# 6      male  54.0      0      0             17463   51.8625          E46
# 7      male   2.0      3      1            349909   21.0750          NaN
# 8    female  27.0      0      2            347742   11.1333          NaN
# 9    female  14.0      1      0            237736   30.0708          NaN
# 10   female   4.0      1      1           PP 9549   16.7000           G6
# 11   female  58.0      0      0            113783   26.5500         C103
# 12     male  20.0      0      0         A/5. 2151    8.0500          NaN
# 13     male  39.0      1      5            347082   31.2750          NaN
# 14   female  14.0      0      0            350406    7.8542          NaN
# 15   female  55.0      0      0            248706   16.0000          NaN
# 16     male   2.0      4      1            382652   29.1250          NaN
# 17     male   NaN      0      0            244373   13.0000          NaN
# 18   female  31.0      1      0            345763   18.0000          NaN
# 19   female   NaN      0      0              2649    7.2250          NaN
# 20     male  35.0      0      0            239865   26.0000          NaN
# 21     male  34.0      0      0            248698   13.0000          D56
# 22   female  15.0      0      0            330923    8.0292          NaN
# 23     male  28.0      0      0            113788   35.5000           A6
# 24   female   8.0      3      1            349909   21.0750          NaN
# 25   female  38.0      1      5            347077   31.3875          NaN
# 26     male   NaN      0      0              2631    7.2250          NaN
# 27     male  19.0      3      2             19950  263.0000  C23 C25 C27
# 28   female   NaN      0      0            330959    7.8792          NaN
# 29     male   NaN      0      0            349216    7.8958          NaN
# ..      ...   ...    ...    ...               ...       ...          ...
# 861    male  21.0      1      0             28134   11.5000          NaN
# 862  female  48.0      0      0             17466   25.9292          D17
# 863  female   NaN      8      2          CA. 2343   69.5500          NaN
# 864    male  24.0      0      0            233866   13.0000          NaN
# 865  female  42.0      0      0            236852   13.0000          NaN
# 866  female  27.0      1      0     SC/PARIS 2149   13.8583          NaN
# 867    male  31.0      0      0          PC 17590   50.4958          A24
# 868    male   NaN      0      0            345777    9.5000          NaN
# 869    male   4.0      1      1            347742   11.1333          NaN
# 870    male  26.0      0      0            349248    7.8958          NaN
# 871  female  47.0      1      1             11751   52.5542          D35
# 872    male  33.0      0      0               695    5.0000  B51 B53 B55
# 873    male  47.0      0      0            345765    9.0000          NaN
# 874  female  28.0      1      0         P/PP 3381   24.0000          NaN
# 875  female  15.0      0      0              2667    7.2250          NaN
# 876    male  20.0      0      0              7534    9.8458          NaN
# 877    male  19.0      0      0            349212    7.8958          NaN
# 878    male   NaN      0      0            349217    7.8958          NaN
# 879  female  56.0      0      1             11767   83.1583          C50
# 880  female  25.0      0      1            230433   26.0000          NaN
# 881    male  33.0      0      0            349257    7.8958          NaN
# 882  female  22.0      0      0              7552   10.5167          NaN
# 883    male  28.0      0      0  C.A./SOTON 34068   10.5000          NaN
# 884    male  25.0      0      0   SOTON/OQ 392076    7.0500          NaN
# 885  female  39.0      0      5            382652   29.1250          NaN
# 886    male  27.0      0      0            211536   13.0000          NaN
# 887  female  19.0      0      0            112053   30.0000          B42
# 888  female   NaN      1      2        W./C. 6607   23.4500          NaN
# 889    male  26.0      0      0            111369   30.0000         C148
# 890    male  32.0      0      0            370376    7.7500          NaN
#
#     embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# 5          Q
# 6          S
# 7          S
# 8          S
# 9          C
# 10         S
# 11         S
# 12         S
# 13         S
# 14         S
# 15         S
# 16         Q
# 17         S
# 18         S
# 19         C
# 20         S
# 21         S
# 22         Q
# 23         S
# 24         S
# 25         S
# 26         C
# 27         S
# 28         Q
# 29         S
# ..       ...
# 861        S
# 862        S
# 863        S
# 864        S
# 865        S
# 866        C
# 867        S
# 868        S
# 869        S
# 870        S
# 871        S
# 872        S
# 873        S
# 874        C
# 875        C
# 876        S
# 877        S
# 878        S
# 879        C
# 880        S
# 881        S
# 882        S
# 883        S
# 884        S
# 885        Q
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 11 columns]

# %%
sample_age.dropna(subset = ['cabin']) # if cabin has na value --> remove the row
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 21          1       2                              Beesley, Mr. Lawrence
# 23          1       1                       Sloper, Mr. William Thompson
# 27          0       1                     Fortune, Mr. Charles Alexander
# 31          1       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 52          1       1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 54          0       1                     Ostby, Mr. Engelhart Cornelius
# 55          1       1                                  Woolner, Mr. Hugh
# 61          1       1                                Icard, Miss. Amelie
# 62          0       1                        Harris, Mr. Henry Birkhardt
# 66          1       2                       Nye, Mrs. (Elizabeth Ramell)
# 75          0       3                            Moen, Mr. Sigurd Hansen
# 88          1       1                         Fortune, Miss. Mabel Helen
# 92          0       1                        Chaffee, Mr. Herbert Fuller
# 96          0       1                          Goldschmidt, Mr. George B
# 97          1       1                    Greenfield, Mr. William Bertram
# 102         0       1                          White, Mr. Richard Frasar
# 110         0       1                     Porter, Mr. Walter Chamberlain
# 118         0       1                           Baxter, Mr. Quigg Edmond
# 123         1       2                                Webber, Miss. Susan
# 124         0       1                        White, Mr. Percival Wayland
# 128         1       3                                  Peter, Miss. Anna
# 136         1       1                       Newsom, Miss. Helen Monypeny
# 137         0       1                        Futrelle, Mr. Jacques Heath
# 139         0       1                                 Giglio, Mr. Victor
# 148         0       2           Navratil, Mr. Michel ("Louis M Hoffman")
# ..        ...     ...                                                ...
# 751         1       3                                Moor, Master. Meier
# 759         1       1  Rothes, the Countess. of (Lucy Noel Martha Dye...
# 763         1       1          Carter, Mrs. William Ernest (Lucile Polk)
# 765         1       1               Hogeboom, Mrs. John C (Anna Andrews)
# 772         0       2                                  Mack, Mrs. (Mary)
# 776         0       3                                   Tobin, Mr. Roger
# 779         1       1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 781         1       1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 782         0       1                             Long, Mr. Milton Clyde
# 789         0       1                           Guggenheim, Mr. Benjamin
# 796         1       1                        Leader, Dr. Alice (Farnham)
# 802         1       1                Carter, Master. William Thornton II
# 806         0       1                             Andrews, Mr. Thomas Jr
# 809         1       1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 815         0       1                                   Fry, Mr. Richard
# 820         1       1  Hays, Mrs. Charles Melville (Clara Jennings Gr...
# 823         1       3                                 Moor, Mrs. (Beila)
# 829         1       1          Stone, Mrs. George Nelson (Martha Evelyn)
# 835         1       1                        Compton, Miss. Sara Rebecca
# 839         1       1                               Marechal, Mr. Pierre
# 849         1       1       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 853         1       1                          Lines, Miss. Mary Conover
# 857         1       1                             Daly, Mr. Peter Denis
# 862         1       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 867         0       1               Roebling, Mr. Washington Augustus II
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         sex   age  sibsp  parch       ticket      fare        cabin embarked
# 1    female  38.0      1      0     PC 17599   71.2833          C85        C
# 3    female  35.0      1      0       113803   53.1000         C123        S
# 6      male  54.0      0      0        17463   51.8625          E46        S
# 10   female   4.0      1      1      PP 9549   16.7000           G6        S
# 11   female  58.0      0      0       113783   26.5500         C103        S
# 21     male  34.0      0      0       248698   13.0000          D56        S
# 23     male  28.0      0      0       113788   35.5000           A6        S
# 27     male  19.0      3      2        19950  263.0000  C23 C25 C27        S
# 31   female   NaN      1      0     PC 17569  146.5208          B78        C
# 52   female  49.0      1      0     PC 17572   76.7292          D33        C
# 54     male  65.0      0      1       113509   61.9792          B30        C
# 55     male   NaN      0      0        19947   35.5000          C52        S
# 61   female  38.0      0      0       113572   80.0000          B28      NaN
# 62     male  45.0      1      0        36973   83.4750          C83        S
# 66   female  29.0      0      0   C.A. 29395   10.5000          F33        S
# 75     male  25.0      0      0       348123    7.6500        F G73        S
# 88   female  23.0      3      2        19950  263.0000  C23 C25 C27        S
# 92     male  46.0      1      0  W.E.P. 5734   61.1750          E31        S
# 96     male  71.0      0      0     PC 17754   34.6542           A5        C
# 97     male  23.0      0      1     PC 17759   63.3583      D10 D12        C
# 102    male  21.0      0      1        35281   77.2875          D26        S
# 110    male  47.0      0      0       110465   52.0000         C110        S
# 118    male  24.0      0      1     PC 17558  247.5208      B58 B60        C
# 123  female  32.5      0      0        27267   13.0000         E101        S
# 124    male  54.0      0      1        35281   77.2875          D26        S
# 128  female   NaN      1      1         2668   22.3583        F E69        C
# 136  female  19.0      0      2        11752   26.2833          D47        S
# 137    male  37.0      1      0       113803   53.1000         C123        S
# 139    male  24.0      0      0     PC 17593   79.2000          B86        C
# 148    male  36.5      0      2       230080   26.0000           F2        S
# ..      ...   ...    ...    ...          ...       ...          ...      ...
# 751    male   6.0      0      1       392096   12.4750         E121        S
# 759  female  33.0      0      0       110152   86.5000          B77        S
# 763  female  36.0      1      2       113760  120.0000      B96 B98        S
# 765  female  51.0      1      0        13502   77.9583          D11        S
# 772  female  57.0      0      0  S.O./P.P. 3   10.5000          E77        S
# 776    male   NaN      0      0       383121    7.7500          F38        Q
# 779  female  43.0      0      1        24160  211.3375           B3        S
# 781  female  17.0      1      0        17474   57.0000          B20        S
# 782    male  29.0      0      0       113501   30.0000           D6        S
# 789    male  46.0      0      0     PC 17593   79.2000      B82 B84        C
# 796  female  49.0      0      0        17465   25.9292          D17        S
# 802    male  11.0      1      2       113760  120.0000      B96 B98        S
# 806    male  39.0      0      0       112050    0.0000          A36        S
# 809  female  33.0      1      0       113806   53.1000           E8        S
# 815    male   NaN      0      0       112058    0.0000         B102        S
# 820  female  52.0      1      1        12749   93.5000          B69        S
# 823  female  27.0      0      1       392096   12.4750         E121        S
# 829  female  62.0      0      0       113572   80.0000          B28      NaN
# 835  female  39.0      1      1     PC 17756   83.1583          E49        C
# 839    male   NaN      0      0        11774   29.7000          C47        C
# 849  female   NaN      1      0        17453   89.1042          C92        C
# 853  female  16.0      0      1     PC 17592   39.4000          D28        S
# 857    male  51.0      0      0       113055   26.5500          E17        S
# 862  female  48.0      0      0        17466   25.9292          D17        S
# 867    male  31.0      0      0     PC 17590   50.4958          A24        S
# 871  female  47.0      1      1        11751   52.5542          D35        S
# 872    male  33.0      0      0          695    5.0000  B51 B53 B55        S
# 879  female  56.0      0      1        11767   83.1583          C50        C
# 887  female  19.0      0      0       112053   30.0000          B42        S
# 889    male  26.0      0      0       111369   30.0000         C148        C
#
# [204 rows x 11 columns]

# %% [markdown]
# ## Remove duplicates
# - drop_duplicates()

# %%
sample_age.drop_duplicates()
# how to check if we have no duplicates
# sample_age.drop_duplicates().info() == sample_age.info()
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 12          0       3                     Saundercock, Mr. William Henry
# 13          0       3                        Andersson, Mr. Anders Johan
# 14          0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16          0       3                               Rice, Master. Eugene
# 17          1       2                       Williams, Mr. Charles Eugene
# 18          0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19          1       3                            Masselmani, Mrs. Fatima
# 20          0       2                               Fynney, Mr. Joseph J
# 21          1       2                              Beesley, Mr. Lawrence
# 22          1       3                        McGowan, Miss. Anna "Annie"
# 23          1       1                       Sloper, Mr. William Thompson
# 24          0       3                      Palsson, Miss. Torborg Danira
# 25          1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26          0       3                            Emir, Mr. Farred Chehab
# 27          0       1                     Fortune, Mr. Charles Alexander
# 28          1       3                      O'Dwyer, Miss. Ellen "Nellie"
# 29          0       3                                Todoroff, Mr. Lalio
# ..        ...     ...                                                ...
# 861         0       2                        Giles, Mr. Frederick Edward
# 862         1       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863         0       3                  Sage, Miss. Dorothy Edith "Dolly"
# 864         0       2                             Gill, Mr. John William
# 865         1       2                           Bystrom, Mrs. (Karolina)
# 866         1       2                       Duran y More, Miss. Asuncion
# 867         0       1               Roebling, Mr. Washington Augustus II
# 868         0       3                        van Melkebeke, Mr. Philemon
# 869         1       3                    Johnson, Master. Harold Theodor
# 870         0       3                                  Balkic, Mr. Cerin
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 873         0       3                        Vander Cruyssen, Mr. Victor
# 874         1       2              Abelson, Mrs. Samuel (Hannah Wizosky)
# 875         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 876         0       3                      Gustafsson, Mr. Alfred Ossian
# 877         0       3                               Petroff, Mr. Nedelio
# 878         0       3                                 Laleff, Mr. Kristo
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 881         0       3                                 Markun, Mr. Johann
# 882         0       3                       Dahlberg, Miss. Gerda Ulrika
# 883         0       2                      Banfield, Mr. Frederick James
# 884         0       3                             Sutehall, Mr. Henry Jr
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket      fare        cabin  \
# 0      male  22.0      1      0         A/5 21171    7.2500          NaN
# 1    female  38.0      1      0          PC 17599   71.2833          C85
# 2    female  26.0      0      0  STON/O2. 3101282    7.9250          NaN
# 3    female  35.0      1      0            113803   53.1000         C123
# 4      male  35.0      0      0            373450    8.0500          NaN
# 5      male   NaN      0      0            330877    8.4583          NaN
# 6      male  54.0      0      0             17463   51.8625          E46
# 7      male   2.0      3      1            349909   21.0750          NaN
# 8    female  27.0      0      2            347742   11.1333          NaN
# 9    female  14.0      1      0            237736   30.0708          NaN
# 10   female   4.0      1      1           PP 9549   16.7000           G6
# 11   female  58.0      0      0            113783   26.5500         C103
# 12     male  20.0      0      0         A/5. 2151    8.0500          NaN
# 13     male  39.0      1      5            347082   31.2750          NaN
# 14   female  14.0      0      0            350406    7.8542          NaN
# 15   female  55.0      0      0            248706   16.0000          NaN
# 16     male   2.0      4      1            382652   29.1250          NaN
# 17     male   NaN      0      0            244373   13.0000          NaN
# 18   female  31.0      1      0            345763   18.0000          NaN
# 19   female   NaN      0      0              2649    7.2250          NaN
# 20     male  35.0      0      0            239865   26.0000          NaN
# 21     male  34.0      0      0            248698   13.0000          D56
# 22   female  15.0      0      0            330923    8.0292          NaN
# 23     male  28.0      0      0            113788   35.5000           A6
# 24   female   8.0      3      1            349909   21.0750          NaN
# 25   female  38.0      1      5            347077   31.3875          NaN
# 26     male   NaN      0      0              2631    7.2250          NaN
# 27     male  19.0      3      2             19950  263.0000  C23 C25 C27
# 28   female   NaN      0      0            330959    7.8792          NaN
# 29     male   NaN      0      0            349216    7.8958          NaN
# ..      ...   ...    ...    ...               ...       ...          ...
# 861    male  21.0      1      0             28134   11.5000          NaN
# 862  female  48.0      0      0             17466   25.9292          D17
# 863  female   NaN      8      2          CA. 2343   69.5500          NaN
# 864    male  24.0      0      0            233866   13.0000          NaN
# 865  female  42.0      0      0            236852   13.0000          NaN
# 866  female  27.0      1      0     SC/PARIS 2149   13.8583          NaN
# 867    male  31.0      0      0          PC 17590   50.4958          A24
# 868    male   NaN      0      0            345777    9.5000          NaN
# 869    male   4.0      1      1            347742   11.1333          NaN
# 870    male  26.0      0      0            349248    7.8958          NaN
# 871  female  47.0      1      1             11751   52.5542          D35
# 872    male  33.0      0      0               695    5.0000  B51 B53 B55
# 873    male  47.0      0      0            345765    9.0000          NaN
# 874  female  28.0      1      0         P/PP 3381   24.0000          NaN
# 875  female  15.0      0      0              2667    7.2250          NaN
# 876    male  20.0      0      0              7534    9.8458          NaN
# 877    male  19.0      0      0            349212    7.8958          NaN
# 878    male   NaN      0      0            349217    7.8958          NaN
# 879  female  56.0      0      1             11767   83.1583          C50
# 880  female  25.0      0      1            230433   26.0000          NaN
# 881    male  33.0      0      0            349257    7.8958          NaN
# 882  female  22.0      0      0              7552   10.5167          NaN
# 883    male  28.0      0      0  C.A./SOTON 34068   10.5000          NaN
# 884    male  25.0      0      0   SOTON/OQ 392076    7.0500          NaN
# 885  female  39.0      0      5            382652   29.1250          NaN
# 886    male  27.0      0      0            211536   13.0000          NaN
# 887  female  19.0      0      0            112053   30.0000          B42
# 888  female   NaN      1      2        W./C. 6607   23.4500          NaN
# 889    male  26.0      0      0            111369   30.0000         C148
# 890    male  32.0      0      0            370376    7.7500          NaN
#
#     embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# 5          Q
# 6          S
# 7          S
# 8          S
# 9          C
# 10         S
# 11         S
# 12         S
# 13         S
# 14         S
# 15         S
# 16         Q
# 17         S
# 18         S
# 19         C
# 20         S
# 21         S
# 22         Q
# 23         S
# 24         S
# 25         S
# 26         C
# 27         S
# 28         Q
# 29         S
# ..       ...
# 861        S
# 862        S
# 863        S
# 864        S
# 865        S
# 866        C
# 867        S
# 868        S
# 869        S
# 870        S
# 871        S
# 872        S
# 873        S
# 874        C
# 875        C
# 876        S
# 877        S
# 878        S
# 879        C
# 880        S
# 881        S
# 882        S
# 883        S
# 884        S
# 885        Q
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# ## DateTime format
# ```python
# pd.to_datetime(series)
# ```

# %%
df = pd.read_csv("superstore_dataset2011-2015.csv", encoding = 'ISO-8859-1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
# Row ID            51290 non-null int64
# Order ID          51290 non-null object
# Order Date        51290 non-null object
# Ship Date         51290 non-null object
# Ship Mode         51290 non-null object
# Customer ID       51290 non-null object
# Customer Name     51290 non-null object
# Segment           51290 non-null object
# City              51290 non-null object
# State             51290 non-null object
# Country           51290 non-null object
# Postal Code       9994 non-null float64
# Market            51290 non-null object
# Region            51290 non-null object
# Product ID        51290 non-null object
# Category          51290 non-null object
# Sub-Category      51290 non-null object
# Product Name      51290 non-null object
# Sales             51290 non-null float64
# Quantity          51290 non-null int64
# Discount          51290 non-null float64
# Profit            51290 non-null float64
# Shipping Cost     51290 non-null float64
# Order Priority    51290 non-null object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 9.4+ MB

# %%
df.sample(2).T
# Out:
#                                         20640                            5100
# Row ID                                  26584                            47068
# Order ID                        ID-2013-30544                     IR-2012-3550
# Order Date                         13-06-2013                         5/9/2012
# Ship Date                          15-06-2013                        10/9/2012
# Ship Mode                         First Class                   Standard Class
# Customer ID                          CL-12700                         TB-11400
# Customer Name                    Craig Leslie                 Tom Boeckenhauer
# Segment                           Home Office                         Consumer
# City                         Ho Chi Minh City                    Khomeynishahr
# State                        Ho Chí Minh City                          Esfahan
# Country                               Vietnam                             Iran
# Postal Code                               NaN                              NaN
# Market                                   APAC                             EMEA
# Region                         Southeast Asia                             EMEA
# Product ID                    TEC-MA-10004298                 TEC-SAM-10001017
# Category                           Technology                       Technology
# Sub-Category                         Machines                           Phones
# Product Name    Panasonic Calculator, Durable  Samsung Speaker Phone, Cordless
# Sales                                  83.664                           756.54
# Quantity                                    2                                6
# Discount                                 0.17                                0
# Profit                                -16.176                           128.52
# Shipping Cost                           11.38                            82.55
# Order Priority                           High                             High

# %%
del df['Row ID']

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
# Order ID          51290 non-null object
# Order Date        51290 non-null datetime64[ns]
# Ship Date         51290 non-null datetime64[ns]
# Ship Mode         51290 non-null object
# Customer ID       51290 non-null object
# Customer Name     51290 non-null object
# Segment           51290 non-null object
# City              51290 non-null object
# State             51290 non-null object
# Country           51290 non-null object
# Postal Code       9994 non-null float64
# Market            51290 non-null object
# Region            51290 non-null object
# Product ID        51290 non-null object
# Category          51290 non-null object
# Sub-Category      51290 non-null object
# Product Name      51290 non-null object
# Sales             51290 non-null float64
# Quantity          51290 non-null int64
# Discount          51290 non-null float64
# Profit            51290 non-null float64
# Shipping Cost     51290 non-null float64
# Order Priority    51290 non-null object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(15)
# memory usage: 9.0+ MB

# %%
df['Order Weekday'] = df['Order Date'].dt.day_name()
df['Ship Weekday'] = df['Ship Date'].dt.day_name()

df['Order Month'] = df['Order Date'].dt.month
df['Ship Month'] = df['Ship Date'].dt.month

df['Order Year'] = df['Order Date'].dt.year
df['Ship Year'] = df['Ship Date'].dt.year

# to convert unixtime to readable time format
# df.convert_time = pd.to_datetime(df.game_action_ts, unit = 'ms')

# %%
df.sample(4)
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 34880    IN-2014-20338 2014-09-21 2014-09-26  Standard Class    VB-21745
# 3631    MX-2012-163279 2012-01-06 2012-03-06    Second Class    RD-19930
# 11712  ES-2013-5056342 2013-09-12 2013-12-15  Standard Class    RD-19480
# 50774     TU-2014-9480 2014-07-31 2014-03-08     First Class    SC-10050
#
#            Customer Name      Segment            City             State  \
# 34880   Victoria Brennan    Corporate          Manila  National Capital
# 3631   Russell D'Ascenzo     Consumer  Ciego de Ávila    Ciego de Ávila
# 11712        Rick Duston     Consumer    Peterborough           England
# 50774   Sample Company A  Home Office        Istanbul          Istanbul
#
#               Country  ...  Discount  Profit Shipping Cost Order Priority  \
# 34880     Philippines  ...      0.45   2.679          1.99         Medium
# 3631             Cuba  ...      0.00   2.800         12.53       Critical
# 11712  United Kingdom  ...      0.00  89.700         26.26            Low
# 50774          Turkey  ...      0.60  -7.596          1.40         Medium
#
#       Order Weekday Ship Weekday Order Month  Ship Month  Order Year  \
# 34880        Sunday       Friday           9           9        2014
# 3631         Friday      Tuesday           1           3        2012
# 11712      Thursday       Sunday           9          12        2013
# 50774      Thursday     Saturday           7           3        2014
#
#        Ship Year
# 34880       2014
# 3631        2012
# 11712       2013
# 50774       2014
#
# [4 rows x 29 columns]

# %% [markdown]
# ## How to do pivot table in Python?

# %% [markdown]
# ### Python VS Excel
# ```python
# pd.pivot_table(data, values = 'col_name', index = 'col_name', columns = 'col_name', aggfunc = 'func')
# ```

# %%
temp = pd.pivot_table(df, values = 'Sales', index = 'Country', columns = 'Order Year', aggfunc = 'sum')
temp.sort_values(by = 'Country').head(10)
# Out:
# Order Year           2011        2012          2013          2014
# Country
# Afghanistan    1729.41000    9071.820    4242.81000    6629.28000
# Albania        1707.54000     948.120     821.25000     411.21000
# Algeria        8539.80000    9288.990    5478.60000   12784.20000
# Angola         6416.91000    3172.980    7919.55000    8044.56000
# Argentina      8739.30512    7037.005   17955.92804   23779.54512
# Armenia         136.26000         NaN      20.49000           NaN
# Australia    137580.06000  203950.842  268971.84900  314733.10200
# Austria       21734.49000   18105.000   23178.00000   29521.56000
# Azerbaijan      802.92000     479.640    2692.98000    1655.97000
# Bahrain               NaN         NaN     669.18000           NaN

# %%
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
str_as_value = pd.pivot_table(df, values = 'Customer ID', index = 'Order Weekday', aggfunc = pd.Series.nunique)
str_as_value.head(10)
# Out:
#                Customer ID
# Order Weekday
# Friday                1310
# Monday                1290
# Saturday              1146
# Sunday                 917
# Thursday              1299
# Tuesday               1335
# Wednesday             1310

# %%
temp3 = pd.pivot_table(df, values = ['Profit', 'Sales'], index = 'Order Weekday', 
                       aggfunc = {'Profit':'sum', 
                                  'Sales':['sum', 'max']})
temp3
# Out:
#                      Profit      Sales
#                         sum        max           sum
# Order Weekday
# Friday         243802.83544  22638.480  2.144812e+06
# Monday         246526.55710  13999.960  2.067053e+06
# Saturday       176486.55222   8749.950  1.433806e+06
# Sunday         104117.90698  17499.950  8.346382e+05
# Thursday       241183.07994  11199.968  2.057502e+06
# Tuesday        249788.05098  10499.970  2.150076e+06
# Wednesday      205552.30862   9892.740  1.954614e+06

# %% [markdown]
# ## Group by
#
#
# ```python
# df.groupby(by = 'col_name').agg(func)
#
# # example
# df = df.groupby('game_name').agg({'col_1':'sum', 'col_2':'sum'})
# ```

# %%
df_g = df.groupby(by = ['Country']).sum()
df_g.sample(5)
# Out:
#                           Postal Code        Sales  Quantity  Discount  \
# Country
# Burundi                           0.0    267.72000         4     0.000
# Central African Republic          0.0   2377.56000        15     0.000
# Panama                            0.0  51539.92752      1426   157.644
# Bolivia                           0.0  11588.97000       174     0.202
# Slovakia                          0.0    865.32000        18     0.000
#
#                                Profit  Shipping Cost  Order Month  Ship Month  \
# Country
# Burundi                     103.08000          18.51           14          18
# Central African Republic    468.54000         403.38           32          16
# Panama                   -17723.45248        5416.24         2795        2924
# Bolivia                    2229.35000        1234.83          357         350
# Slovakia                    115.26000          86.10           31          46
#
#                           Order Year  Ship Year
# Country
# Burundi                         4023       4023
# Central African Republic       14088      14088
# Panama                        780994     781001
# Bolivia                        96615      96615
# Slovakia                       16093      16093

# %%
df_g1 = df.groupby(by = ['Country', 'Order Year']).agg({
    'Quantity': 'mean',
    'Profit': 'mean',
    'Sales': 'mean', 
    'Shipping Cost': 'mean'})

df_g1.head(10)
# Out:
#                         Quantity      Profit       Sales  Shipping Cost
# Country     Order Year
# Afghanistan 2011        5.111111   32.660000  192.156667      18.357778
#             2012        4.066667  128.276000  604.788000      75.201333
#             2013        3.750000   95.745000  353.567500      30.488333
#             2014        4.000000  110.172632  348.909474      33.743684
# Albania     2011        3.000000   53.508000  341.508000      61.636000
#             2012        1.600000   58.260000  189.624000      14.462000
#             2013        2.000000   20.990000  273.750000      89.953333
#             2014        3.666667   29.170000  137.070000      16.073333
# Algeria     2011        2.806452   56.010000  275.477419      33.336774
#             2012        2.282609   48.218478  201.934565      18.865652

# %% [markdown]
# ## Order by
# ```python
# df.sort_values(by = 'col_name', ascending = True)
# ```

# %%
df_g1.sort_values(by = 'Profit', ascending = False).head(5)
# Out:
#                        Quantity  Profit      Sales  Shipping Cost
# Country    Order Year
# Lesotho    2013           12.00  455.76  3799.0800     369.730000
# Montenegro 2014            3.25  321.69  1001.0925      93.937500
# Slovenia   2014            9.00  269.73   658.2600      89.095000
# Estonia    2012            2.50  245.10   941.2800      82.495000
# Mauritania 2013            4.00  212.74   504.3000      66.823333

# %% [markdown]
# ## How to combine multiple datasets?
# - concat
# - join
# - merge

# %% [markdown]
# ### Combine Data
# - Concat
#     - default: outer
#
# ```python
# pd.concat([df1, df2], join = 'inner')
# ```

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                   index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                   index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                   index=[8, 9, 10, 11])

df4 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                   index=[0, 1, 2, 3])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df3], axis = 1)
# Out:
#       A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df4
# Out:
#      A    B    C    D
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
pd.concat([df1, df4])
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
pd.concat([df1, df4], axis = 1)
# Out:
#     A   B   C   D    A    B    C    D
# 0  A0  B0  C0  D0   A8   B8   C8   D8
# 1  A1  B1  C1  D1   A9   B9   C9   D9
# 2  A2  B2  C2  D2  A10  B10  C10  D10
# 3  A3  B3  C3  D3  A11  B11  C11  D11

# %% [markdown]
# ### Combine Data
# - Join
#     - default: how = 'left'
#     - join on index
#
# ```python
# df1.join(df2, how = 'left', on = 'col_name')
# ```
#
# - **\*Merge**
#     - default: how = 'inner'
#
# ```python
# df1.merge(df2, how = 'left', left_on = 'col_name', right_on = 'col_name')
#
# df1.join(df2, how = 'left', on = 'col_name', sort = False).reset_index()
# ```
# <p><p>
#
# - More Details: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
# left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
#                      'B': ['B0', 'B1', 'B2']},
#                     index=['K0', 'K1', 'K2'])
# right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
#                       'D': ['D0', 'D2', 'D3']},
#                      index=['K0', 'K2', 'K3'])

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
left.merge(right, on = ['key1', 'key2'], how = 'left')
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
left.merge(right, on = ['key1', 'key2'], how = 'left')
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
left.join(right, how = 'left', lsuffix = '_l', rsuffix = '_r')
# Out:
#   key1_l key2_l   A   B key1_r key2_r   C   D
# 0     K0     K0  A0  B0     K0     K0  C0  D0
# 1     K0     K1  A1  B1     K1     K0  C1  D1
# 2     K1     K0  A2  B2     K1     K0  C2  D2
# 3     K2     K1  A3  B3     K2     K0  C3  D3

# %%
left = left.set_index(['key1', 'key2'])
right = right.set_index(['key1', 'key2'])

# %%
left
# Out:
#             A   B
# key1 key2
# K0   K0    A0  B0
#      K1    A1  B1
# K1   K0    A2  B2
# K2   K1    A3  B3

# %%
right
# Out:
#             C   D
# key1 key2
# K0   K0    C0  D0
# K1   K0    C1  D1
#      K0    C2  D2
# K2   K0    C3  D3

# %%
# join can only by index, if have repeated column name, need r/lsuffix for rename

left.join(right, lsuffix = '_l', rsuffix = '_r')
# Out:
#             A   B    C    D
# key1 key2
# K0   K0    A0  B0   C0   D0
#      K1    A1  B1  NaN  NaN
# K1   K0    A2  B2   C1   D1
#      K0    A2  B2   C2   D2
# K2   K1    A3  B3  NaN  NaN

# %%
left.merge(right, on = ['key1', 'key2'], how = 'left')
# Out:
#             A   B    C    D
# key1 key2
# K0   K0    A0  B0   C0   D0
#      K1    A1  B1  NaN  NaN
# K1   K0    A2  B2   C1   D1
#      K0    A2  B2   C2   D2
# K2   K1    A3  B3  NaN  NaN

# %%
left = left.reset_index()
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %% [markdown]
# ## Save my DataFrame as csv file

# %% [markdown]
# ### Export
# ```python
# df.to_csv(path)
# df.to_excel(path)
# df.to_json(path)
# ```

# %%
save_path = 'tutorial_left.csv'
left.to_csv(save_path)

# %%
save_path = 'tutorial_left.xlsx'
left.to_excel(save_path, sheet_name = 'left')
